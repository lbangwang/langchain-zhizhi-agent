# %% [markdown]
# #1. 调用本地千问大模型

# %%
import os

from dotenv import load_dotenv
from langchain_community.chat_models import ChatTongyi, ChatOllama

# 加载配置文件，存在相同key采用当前覆盖
load_dotenv(override=True)

tongyi_res = ChatOllama(
    model="qwen3.5:0.8b",
    base_url="http://127.0.0.1:11434",

)
print(tongyi_res.invoke("你好，请你介绍一下自己"))
# Out:
# /var/folders/9s/8yvtv66d0270gc20zts9h86r0000gn/T/ipykernel_33851/1405141846.py:9: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   tongyi_res = ChatOllama(
# content='您好！我是 Qwen3.5，一款由阿里巴巴通义实验室自主研发的超大规模多模态对话模型。虽然我不能直接“公开”个人隐私信息（例如姓名），但我可以主动协助您完成需要帮助的工作：比如帮您解答问题、撰写文档或规划行程等——请随时分享您的需求哦！😊' additional_kwargs={} response_metadata={'model': 'qwen3.5:0.8b', 'created_at': '2026-08-08T04:04:49.138627Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 6080101916, 'load_duration': 2044609625, 'prompt_eval_count': 238, 'prompt_eval_duration': 179663000, 'eval_count': 67, 'eval_duration': 849589000} id='lc_run--019fdf8b-67b0-7410-ae27-a9eb63d2ddbf-0' tool_calls=[] invalid_tool_calls=[]
