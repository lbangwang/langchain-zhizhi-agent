# %% [markdown]
# #1. 模型调用方法invoke()参数 文本输入

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 加载配置文件，存在相同key采用当前覆盖
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_API_BASE   = os.getenv("DEEPSEEK_BASE_URL")
DEEPSEEK_MODEL_NAME   = os.getenv("DEEPSEEK_MODEL")

deepseek_res = ChatDeepSeek(
    model_name=DEEPSEEK_MODEL_NAME,
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_API_BASE,
)
# 文本输入
print(deepseek_res.invoke("你好，请你介绍一下自己，只用10个字"))
# Out:
# content='我是深度求索人工智能' additional_kwargs={'refusal': None, 'reasoning_content': '我们只需要回答10个字。介绍自己。可以说“我是DeepSeek，AI助手。” 字数？中文字数：我(1)是(2)DeepSeek(算英文？) 要求“10个字”可能指中文汉字。需要精确10个汉字。可以说“我是深度求索AI助手” 字数：我1是2深3度4求5索6A7I8助9手10？但“AI”算两个字母，可能不算字。最好全中文：“我是深度求索人工智能” 我1是2深3度4求5索6人7工8智9能10。好。'} response_metadata={'token_usage': {'completion_tokens': 144, 'prompt_tokens': 92, 'total_tokens': 236, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 138, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 92}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_a18b46594c_prod0820_fp8_kvcache_20260402', 'id': '9fe5841e-d595-4846-adcc-9a9c5f291da4', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ff015-d1a3-7c32-ac00-107889c96cc1-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 92, 'output_tokens': 144, 'total_tokens': 236, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 138}}
